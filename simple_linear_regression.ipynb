# %%
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#equation
#y=mx+c
m=50
c=36

# %%
x=np.random.randint(0,50000,200) # generating random x_values
y=np.array(list(map(lambda x:m*x+c,x))) # applying the equation on x to get y values
y
# Out:
# array([1664236,  296786, 1350186, 1423536,  537086, 1567736, 1384036,
#         170636,  535386,  133986, 1475686,   49236, 1643736,  964636,
#        2210836, 2160686, 1651886, 2166636, 1651286,   89686,  358986,
#        1954036,  272636, 1027136,  173836,  520786,  213486,  380536,
#         847436, 1993386,  777186,   69686,  433686,  977636, 1509136,
#        1634236, 1931186, 1789536, 1094786,  380886, 1203986, 2247036,
#        2145436, 2440686,   31886,  412486,  607786,  740136, 1078136,
#        1190986, 2231436, 1376486,  992236,  245586, 1440386, 1508886,
#         489986,  170586,  837886, 2319036,  521986, 1899586,   50386,
#        1014736,  968536,  441586, 1737886, 2270036,  489836, 1191136,
#        1828236, 2043486, 1401686, 1766286,  986136, 1876436,  364486,
#        2060086, 2127836, 1138336, 1900786, 1672436, 2294386, 1729336,
#         122936, 1337036,   83036,  330736, 1944736, 1093936, 1790686,
# ...

# %%
#adding noice on y
mean=0
std=20 #small value for accurate model
noice=np.random.normal(mean,std,len(y))
noiced_y=y+noice
####the best noice type,mean,std??

# %%
#split data 80:20
x=x.reshape(-1,1)
#########whhyyyyy??????????
X_train, X_test, y_train, y_test = train_test_split(
    x, noiced_y, test_size=0.2, random_state=0)

# %%
#model fit
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(model.coef_,model.intercept_)
# Out:
# [49.99998303] 36.554219868266955

# %%
predictions_train=model.predict(X_train)

# %%
sns.scatterplot(x=X_train.ravel(),y=y_train)
sns.lineplot(x=X_train.ravel(),y=predictions_train,color='red')
# Out:
# <Axes: >

# %%
predictions_test=model.predict(X_test)

# %%
sns.scatterplot(x=X_test.ravel(),y=y_test)
sns.lineplot(x=X_test.ravel(),y=predictions_test,color='red')
####why x_test is 2d??????????
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
print("MSE: train: ",mean_squared_error(y_train,predictions_train)," test: ",mean_squared_error(y_test,predictions_test))
# Out:
# MSE: train:  385.39380845157365  test:  502.7981388073187

# %%
print("MAE: train: ",mean_absolute_error(y_train,predictions_train)," test: ",mean_absolute_error(y_test,predictions_test))
# Out:
# MAE: train:  15.16442361154717  test:  18.49646365023873

# %%
print("R2: train: ",r2_score(y_train,predictions_train)," test: ",r2_score(y_test,predictions_test))
# Out:
# R2: train:  0.9999999993057593  test:  0.9999999988571973

# %% [markdown]
# model is almost good
